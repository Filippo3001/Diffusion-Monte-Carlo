# %%
import sys
import os

sys.path.append(os.path.abspath("/home/filippo/Github/Varational-Monte-Carlo/src"))

import numpy as np
import sympy as smp
import functions_smp as fsmp

# %%
print(fsmp.He_trial_function)
# Out:
# (a*exp((-beta - gamma)*((r1x - r2x)**2 + (r1y - r2y)**2 + (r1z - r2z)**2)) + exp(-gamma*((r1x - r2x)**2 + (r1y - r2y)**2 + (r1z - r2z)**2)))*(a*exp((-beta - gamma)*((r1x - r3x)**2 + (r1y - r3y)**2 + (r1z - r3z)**2)) + exp(-gamma*((r1x - r3x)**2 + (r1y - r3y)**2 + (r1z - r3z)**2)))*(a*exp((-beta - gamma)*((r1x - r4x)**2 + (r1y - r4y)**2 + (r1z - r4z)**2)) + exp(-gamma*((r1x - r4x)**2 + (r1y - r4y)**2 + (r1z - r4z)**2)))*(a*exp((-beta - gamma)*((r2x - r3x)**2 + (r2y - r3y)**2 + (r2z - r3z)**2)) + exp(-gamma*((r2x - r3x)**2 + (r2y - r3y)**2 + (r2z - r3z)**2)))*(a*exp((-beta - gamma)*((r2x - r4x)**2 + (r2y - r4y)**2 + (r2z - r4z)**2)) + exp(-gamma*((r2x - r4x)**2 + (r2y - r4y)**2 + (r2z - r4z)**2)))*(a*exp((-beta - gamma)*((r3x - r4x)**2 + (r3y - r4y)**2 + (r3z - r4z)**2)) + exp(-gamma*((r3x - r4x)**2 + (r3y - r4y)**2 + (r3z - r4z)**2)))

# %%
print(fsmp.local_en)
# Out:
# ((a*exp((-beta - gamma)*((r1x - r2x)**2 + (r1y - r2y)**2 + (r1z - r2z)**2)) + exp(-gamma*((r1x - r2x)**2 + (r1y - r2y)**2 + (r1z - r2z)**2)))*(a*exp((-beta - gamma)*((r1x - r3x)**2 + (r1y - r3y)**2 + (r1z - r3z)**2)) + exp(-gamma*((r1x - r3x)**2 + (r1y - r3y)**2 + (r1z - r3z)**2)))*(a*exp((-beta - gamma)*((r1x - r4x)**2 + (r1y - r4y)**2 + (r1z - r4z)**2)) + exp(-gamma*((r1x - r4x)**2 + (r1y - r4y)**2 + (r1z - r4z)**2)))*(a*exp((-beta - gamma)*((r2x - r3x)**2 + (r2y - r3y)**2 + (r2z - r3z)**2)) + exp(-gamma*((r2x - r3x)**2 + (r2y - r3y)**2 + (r2z - r3z)**2)))*(a*exp((-beta - gamma)*((r2x - r4x)**2 + (r2y - r4y)**2 + (r2z - r4z)**2)) + exp(-gamma*((r2x - r4x)**2 + (r2y - r4y)**2 + (r2z - r4z)**2)))*(a*exp((-beta - gamma)*((r3x - r4x)**2 + (r3y - r4y)**2 + (r3z - r4z)**2)) + exp(-gamma*((r3x - r4x)**2 + (r3y - r4y)**2 + (r3z - r4z)**2)))*(1000*exp(-3*(r1x - r2x)**2 - 3*(r1y - r2y)**2 - 3*(r1z - r2z)**2) - 163.5*exp(-1.05*(r1x - r2x)**2 - 1.05*(r1y - r2y)**2 - 1.05*(r1z - r2z)**2) - 83*e
# ...

# %%
fsmp.He_trial_function.subs({fsmp.r1x:1, fsmp.r1y:0, fsmp.r1z:0, fsmp.r2x:1, fsmp.r2y:1, fsmp.r2z:0, fsmp.r3x:0,
                         fsmp.r3y:1, fsmp.r3z:0, fsmp.r4x:0, fsmp.r4y:0, fsmp.r4z:1, fsmp.a:1, fsmp.beta:2, fsmp.gamma:0.5})
# Out:
# 0.00557636298990424

# %%
fsmp.local_en.subs({fsmp.r1x:1, fsmp.r1y:0, fsmp.r1z:0, fsmp.r2x:1, fsmp.r2y:1, fsmp.r2z:0, fsmp.r3x:0,
                         fsmp.r3y:1, fsmp.r3z:0, fsmp.r4x:0, fsmp.r4y:0, fsmp.r4z:1, fsmp.a:1, fsmp.beta:2, fsmp.gamma:0.5}).evalf()
# Out:
# -263.964108661034
